# %% [markdown]
# <a href="https://colab.research.google.com/github/saai07/Content_Creation_AGENT/blob/main/conten_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from crewai import Task, Agent, Crew
import os
os.environ["CREWAI_TESTING"] = "true"
from open_api_key import api_key


os.environ["OPENAI_API_KEY"] = api_key

# %%
# Define the Content Planning Agent
content_creator_assistant = Agent(
    role="YouTube Shorts Micro-History Strategist",
    goal="Plan a 1-week slate of high-retention YouTube Shorts about surprising origins of everyday things.",
    backstory=(
        "You specialize in 30–45s micro-history that hooks fast, pays off with a twist, and drives comments. "
        "You keep ideas filmable by a solo creator at home with minimal props."
    ),
    llm="gpt-4o-mini",
    verbose=True
)

print("✓ Content planning agent defined")
# Out:
# ✓ Content planning agent defined

# %%
# Define the Content Planning Task
task = Task(
    description=(
        "Create a 1-week video posting plan with 5 video blueprints. "
        "Platform: YouTube Shorts (vertical 9:16, 30-45s). "
        "Niche: Micro-History of Everyday Things (e.g., why pencils are yellow, origins of bubble wrap, etc.). "
        "Primary goals: 1) thumb-stop hook in first 1s, 2) crystal-clear narrative with a surprise, "
        "3) strong SEO phrasing in title/caption, 4) comment-bait CTA. "
        "Context: solo creator, home-filmable, no special gear. "
    ),
    expected_output=(
        '''
        Output a JSON array following the schema below, which contains a
        weekly schedule and 5 video blueprints. Each video blueprint should include:
        {
          "videos": [
            {
              "title": "<searchable, curiosity-driven title>",
              "hook_main": "<<=12 words, shows payoff fast>",
              "hook_alt": "<variant hook>",
              "visuals": ["simple prop or b-roll idea 1", "idea 2"],
              "tags": ["#microhistory","#everydaythings","#shorts"],
              "cta": "<question that invites comments>"
            }
          ]
        }
        '''
    ),
    agent=content_creator_assistant
)

print("✓ Content planning task defined")
# Out:
# ✓ Content planning task defined

# %%
# Create the content planning crew
crew = Crew(
    agents=[content_creator_assistant],
    tasks=[task]
)

print("✓ Content planning crew created")
print("\n Starting content planning...\n")

# Execute the crew's task
result = crew.kickoff()

print("\n✓ Content planning complete!")
# Out:
# ✓ Content planning crew created
#
#  Starting content planning...
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: YouTube Shorts Micro-History Strategist                                                                 │
# │                                                                                                                 │
# │  Task: Create a 1-week video posting plan with 5 video blueprints. Platform: YouTube Shorts (vertical 9:16,     │
# │  30-45s). Niche: Micro-History of Everyday Things (e.g., why pencils are yellow, origins of bubble wrap,        │
# │  etc.). Primary goals: 1) thumb-stop hook in first 1s, 2) crystal-clear narrative with a surprise, 3) strong    │
# │  SEO phrasing in title/caption, 4) comment-bait CTA. Context: solo creator, home-filmable, no special gear.     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ERROR:root:OpenAI API call failed: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# ERROR:root:OpenAI API call failed: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# An unknown error occurred. Please check the details below.
# Error details: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# An unknown error occurred. Please check the details below.
# Error details: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-2506986108.py in <cell line: 0>()
#      10 # Execute the crew's task
# ---> 11 result = crew.kickoff()
#      12
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in kickoff(self, inputs)
#     754             if self.process == Process.sequential:
# --> 755                 result = self._run_sequential_process()
#     756             elif self.process == Process.hierarchical:
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _run_sequential_process(self)
#     994         """Executes tasks sequentially and returns the final output."""
# --> 995         return self._execute_tasks(self.tasks)
#     996
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _execute_tasks(self, tasks, start_index, was_replayed)
#    1102                 context = self._get_context(task, task_outputs)
# -> 1103                 task_output = task.execute_sync(
#    1104                     agent=agent_to_use,
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in execute_sync(self, agent, context, tools)
#     457         """Execute the task synchronously."""
# --> 458         return self._execute_core(agent, context, tools)
#     459
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     590             crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 591             raise e  # Re-raise the exception after emitting the event
#     592
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     521             crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 522             result = agent.execute_task(
#     523                 task=self,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     524                 )
# --> 525                 raise e
#     526             result = self.execute_task(task, context, tools)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     489             else:
# --> 490                 result = self._execute_without_timeout(task_prompt, task)
#     491
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _execute_without_timeout(self, task_prompt, task)
#     597
# --> 598         return self.agent_executor.invoke(
#     599             {
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in invoke(self, inputs)
#     187         try:
# --> 188             formatted_answer = self._invoke_loop()
#     189         except AssertionError:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     298                 handle_unknown_error(self._printer, e)
# --> 299                 raise e
#     300             finally:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     228
# --> 229                 answer = get_llm_response(
#     230                     llm=self.llm,
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     275     except Exception as e:
# --> 276         raise e
#     277     if not answer:
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     267     try:
# --> 268         answer = llm.call(
#     269             messages,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     196
# --> 197             return self._handle_completion(
#     198                 params=completion_params,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#     427             )
# --> 428             raise e from e
#     429
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#     343
# --> 344             response: ChatCompletion = self.client.chat.completions.create(**params)
#     345
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1188         validate_response_format(response_format)
# -> 1189         return self._post(
#    1190             "/chat/completions",
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1046                 log.debug("Re-raising status error")
# -> 1047                 raise self._make_status_error_from_response(err.response) from None
#    1048
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# The above exception was the direct cause of the following exception:
#
# RateLimitError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# /tmp/ipython-input-2506986108.py in <cell line: 0>()
#      10 # Execute the crew's task
# ---> 11 result = crew.kickoff()
#      12
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in kickoff(self, inputs)
#     754             if self.process == Process.sequential:
# --> 755                 result = self._run_sequential_process()
#     756             elif self.process == Process.hierarchical:
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _run_sequential_process(self)
#     994         """Executes tasks sequentially and returns the final output."""
# --> 995         return self._execute_tasks(self.tasks)
#     996
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _execute_tasks(self, tasks, start_index, was_replayed)
#    1102                 context = self._get_context(task, task_outputs)
# -> 1103                 task_output = task.execute_sync(
#    1104                     agent=agent_to_use,
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in execute_sync(self, agent, context, tools)
#     457         """Execute the task synchronously."""
# --> 458         return self._execute_core(agent, context, tools)
#     459
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     590             crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 591             raise e  # Re-raise the exception after emitting the event
#     592
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     521             crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 522             result = agent.execute_task(
#     523                 task=self,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     524                 )
# --> 525                 raise e
#     526             result = self.execute_task(task, context, tools)
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     489             else:
# --> 490                 result = self._execute_without_timeout(task_prompt, task)
#     491
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _execute_without_timeout(self, task_prompt, task)
#     597
# --> 598         return self.agent_executor.invoke(
#     599             {
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in invoke(self, inputs)
#     187         try:
# --> 188             formatted_answer = self._invoke_loop()
#     189         except AssertionError:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     298                 handle_unknown_error(self._printer, e)
# --> 299                 raise e
#     300             finally:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     228
# --> 229                 answer = get_llm_response(
#     230                     llm=self.llm,
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     275     except Exception as e:
# --> 276         raise e
#     277     if not answer:
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     267     try:
# --> 268         answer = llm.call(
#     269             messages,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     196
# --> 197             return self._handle_completion(
#     198                 params=completion_params,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#     427             )
# --> 428             raise e from e
#     429
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#     343
# --> 344             response: ChatCompletion = self.client.chat.completions.create(**params)
#     345
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1188         validate_response_format(response_format)
# -> 1189         return self._post(
#    1190             "/chat/completions",
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1046                 log.debug("Re-raising status error")
# -> 1047                 raise self._make_status_error_from_response(err.response) from None
#    1048
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# The above exception was the direct cause of the following exception:
#
# RateLimitError                            Traceback (most recent call last)
# /tmp/ipython-input-2506986108.py in <cell line: 0>()
#       9
#      10 # Execute the crew's task
# ---> 11 result = crew.kickoff()
#      12
#      13 print("\n✓ Content planning complete!")
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in kickoff(self, inputs)
#     753
#     754             if self.process == Process.sequential:
# --> 755                 result = self._run_sequential_process()
#     756             elif self.process == Process.hierarchical:
#     757                 result = self._run_hierarchical_process()
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _run_sequential_process(self)
#     993     def _run_sequential_process(self) -> CrewOutput:
#     994         """Executes tasks sequentially and returns the final output."""
# --> 995         return self._execute_tasks(self.tasks)
#     996
#     997     def _run_hierarchical_process(self) -> CrewOutput:
#
# /usr/local/lib/python3.12/dist-packages/crewai/crew.py in _execute_tasks(self, tasks, start_index, was_replayed)
#    1101
#    1102                 context = self._get_context(task, task_outputs)
# -> 1103                 task_output = task.execute_sync(
#    1104                     agent=agent_to_use,
#    1105                     context=context,
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in execute_sync(self, agent, context, tools)
#     456     ) -> TaskOutput:
#     457         """Execute the task synchronously."""
# --> 458         return self._execute_core(agent, context, tools)
#     459
#     460     @property
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     589             self.end_time = datetime.datetime.now()
#     590             crewai_event_bus.emit(self, TaskFailedEvent(error=str(e), task=self))  # type: ignore[no-untyped-call]
# --> 591             raise e  # Re-raise the exception after emitting the event
#     592
#     593     def prompt(self) -> str:
#
# /usr/local/lib/python3.12/dist-packages/crewai/task.py in _execute_core(self, agent, context, tools)
#     520             self.processed_by_agents.add(agent.role)
#     521             crewai_event_bus.emit(self, TaskStartedEvent(context=context, task=self))  # type: ignore[no-untyped-call]
# --> 522             result = agent.execute_task(
#     523                 task=self,
#     524                 context=context,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     523                     ),
#     524                 )
# --> 525                 raise e
#     526             result = self.execute_task(task, context, tools)
#     527
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in execute_task(self, task, context, tools)
#     488                 )
#     489             else:
# --> 490                 result = self._execute_without_timeout(task_prompt, task)
#     491
#     492         except TimeoutError as e:
#
# /usr/local/lib/python3.12/dist-packages/crewai/agent/core.py in _execute_without_timeout(self, task_prompt, task)
#     596             raise RuntimeError("Agent executor is not initialized.")
#     597
# --> 598         return self.agent_executor.invoke(
#     599             {
#     600                 "input": task_prompt,
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in invoke(self, inputs)
#     186
#     187         try:
# --> 188             formatted_answer = self._invoke_loop()
#     189         except AssertionError:
#     190             self._printer.print(
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     297                     continue
#     298                 handle_unknown_error(self._printer, e)
# --> 299                 raise e
#     300             finally:
#     301                 self.iterations += 1
#
# /usr/local/lib/python3.12/dist-packages/crewai/agents/crew_agent_executor.py in _invoke_loop(self)
#     227                 enforce_rpm_limit(self.request_within_rpm_limit)
#     228
# --> 229                 answer = get_llm_response(
#     230                     llm=self.llm,
#     231                     messages=self.messages,
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     274         )
#     275     except Exception as e:
# --> 276         raise e
#     277     if not answer:
#     278         printer.print(
#
# /usr/local/lib/python3.12/dist-packages/crewai/utilities/agent_utils.py in get_llm_response(llm, messages, callbacks, printer, from_task, from_agent, response_model, executor_context)
#     266
#     267     try:
# --> 268         answer = llm.call(
#     269             messages,
#     270             callbacks=callbacks,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in call(self, messages, tools, callbacks, available_functions, from_task, from_agent, response_model)
#     195                 )
#     196
# --> 197             return self._handle_completion(
#     198                 params=completion_params,
#     199                 available_functions=available_functions,
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#     426                 error=error_msg, from_task=from_task, from_agent=from_agent
#     427             )
# --> 428             raise e from e
#     429
#     430         return content
#
# /usr/local/lib/python3.12/dist-packages/crewai/llms/providers/openai/completion.py in _handle_completion(self, params, available_functions, from_task, from_agent, response_model)
#     342                     return structured_json
#     343
# --> 344             response: ChatCompletion = self.client.chat.completions.create(**params)
#     345
#     346             usage = self._extract_openai_token_usage(response)
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     284                         msg = f"Missing required argument: {quote(missing[0])}"
#     285                 raise TypeError(msg)
# --> 286             return func(*args, **kwargs)
#     287
#     288         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1187     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1188         validate_response_format(response_format)
# -> 1189         return self._post(
#    1190             "/chat/completions",
#    1191             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#    1261     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1045
#    1046                 log.debug("Re-raising status error")
# -> 1047                 raise self._make_status_error_from_response(err.response) from None
#    1048
#    1049             break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
print("=" * 80)
print("WEEKLY CONTENT PLAN")
print("=" * 80)
print(result.raw)
# Out:
# ================================================================================
# WEEKLY CONTENT PLAN
# ================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1556195884.py in <cell line: 0>()
#       2 print("WEEKLY CONTENT PLAN")
#       3 print("=" * 80)
# ----> 4 print(result.raw)
#
# NameError: name 'result' is not defined
